# %% [markdown]
# # **STABLE DIFFUSION DEVELOPMENT TOOL**

# %% [markdown]
# ## **How to Run?**
# ### **The code can run either on Colab or Local Host Server.**
#   1. ....

# %% [markdown]
# ## **Mount to Github (only run if you are using Github)**

# %%
! apt-get install git

uname = "changxu001"
# !git config --global user.email 'adamlisla@gmail.com'
# !git config --global user.name 'changxu001'

# !git clone https://github.com/changxu001/Stabl_Diffusion_UD.git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# fatal: destination path 'Stabl_Diffusion_UD' already exists and is not an empty directory.

# %%
# %cd /content/Stabl_Diffusion_UD
# %ls
# Out:
# /content/Stabl_Diffusion_UD
# 0718_Stable_Diffusion_Tool.ipynb  model/  README.md

# %%
#### Push the changes to Github!!!
github_token = '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'

# !git add -A
# !git commit -m'misc'
# Out:
# [main 984d8e8] misc
#  467 files changed, 63434 insertions(+)
#  create mode 100644 model/sd/generative-models/.gitignore
#  create mode 100644 model/sd/generative-models/.gitsub/HEAD
#  create mode 100644 model/sd/generative-models/.gitsub/config
#  create mode 100644 model/sd/generative-models/.gitsub/description
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/applypatch-msg.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/commit-msg.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/fsmonitor-watchman.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/post-update.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-applypatch.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-commit.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-merge-commit.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-push.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-rebase.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/pre-receive.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/prepare-commit-msg.sample
#  create mode 100755 model/sd/generative-models/.gitsub/hooks/update.sample
#  create mode 100644 model/sd/generative-models/.gitsub/index
#  create mode 100644 model/sd/generative-models/.gitsub/info/exclude
#  create mode 100644 model/sd/generative-models/.gitsub/logs/HEAD
#  create mode 100644 model/sd/generative-models/.gitsub/logs/refs/heads/main
#  create mode 100644 model/sd/generative-models/.gitsub/logs/refs/remotes/origin/HEAD
#  create mode 100644 model/sd/generative-models/.gitsub/objects/pack/pack-63f8dcb96a3a1baf99f3d161746941b2d19be356.idx
#  create mode 100644 model/sd/generative-models/.gitsub/objects/pack/pack-63f8dcb96a3a1baf99f3d161746941b2d19be356.pack
#  create mode 100644 model/sd/generative-models/.gitsub/packed-refs
#  create mode 100644 model/sd/generative-models/.gitsub/refs/heads/main
#  create mode 100644 model/sd/generative-models/.gitsub/refs/remotes/origin/HEAD
#  create mode 100644 model/sd/generative-models/LICENSE
#  create mode 100644 model/sd/generative-models/README.md
#  create mode 100644 model/sd/generative-models/assets/000.jpg
#  create mode 100644 model/sd/generative-models/assets/sdxl_report.pdf
#  create mode 100644 model/sd/generative-models/configs/example_training/autoencoder/kl-f4/imagenet-attnfree-logvar.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/imagenet-f8_cond.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/cifar10_cond.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/mnist.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/mnist_cond.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/mnist_cond_discrete_eps.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/mnist_cond_l1_loss.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/toy/mnist_cond_with_ema.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/txt2img-clipl-legacy-ucg-training.yaml
#  create mode 100644 model/sd/generative-models/configs/example_training/txt2img-clipl.yaml
#  create mode 100644 model/sd/generative-models/configs/inference/sd_2_1.yaml
#  create mode 100644 model/sd/generative-models/configs/inference/sd_2_1_768.yaml
#  create mode 100644 model/sd/generative-models/configs/inference/sd_xl_base.yaml
#  create mode 100644 model/sd/generative-models/configs/inference/sd_xl_refiner.yaml
#  create mode 100644 model/sd/generative-models/data/DejaVuSans.ttf
#  create mode 100644 model/sd/generative-models/main.py
#  create mode 100644 model/sd/generative-models/requirements_pt13.txt
#  create mode 100644 model/sd/generative-models/requirements_pt2.txt
#  create mode 100644 model/sd/generative-models/scripts/__init__.py
#  create mode 100644 model/sd/generative-models/scripts/demo/__init__.py
#  create mode 100644 model/sd/generative-models/scripts/demo/detect.py
#  create mode 100644 model/sd/generative-models/scripts/demo/sampling.py
#  create mode 100644 model/sd/generative-models/scripts/demo/streamlit_helpers.py
#  create mode 100644 model/sd/generative-models/scripts/util/__init__.py
#  create mode 100644 model/sd/generative-models/scripts/util/detection/__init__.py
#  create mode 100644 model/sd/generative-models/scripts/util/detection/nsfw_and_watermark_dectection.py
#  create mode 100644 model/sd/generative-models/scripts/util/detection/p_head_v1.npz
#  create mode 100644 model/sd/generative-models/scripts/util/detection/w_head_v1.npz
#  create mode 100644 model/sd/generative-models/setup.py
#  create mode 100644 model/sd/generative-models/sgm/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/data/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/data/cifar10.py
#  create mode 100644 model/sd/generative-models/sgm/data/dataset.py
#  create mode 100644 model/sd/generative-models/sgm/data/mnist.py
#  create mode 100644 model/sd/generative-models/sgm/lr_scheduler.py
#  create mode 100644 model/sd/generative-models/sgm/models/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/models/autoencoder.py
#  create mode 100644 model/sd/generative-models/sgm/models/diffusion.py
#  create mode 100644 model/sd/generative-models/sgm/modules/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/attention.py
#  create mode 100644 model/sd/generative-models/sgm/modules/autoencoding/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/autoencoding/losses/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/autoencoding/regularizers/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/denoiser.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/denoiser_scaling.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/denoiser_weighting.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/discretizer.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/guiders.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/loss.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/model.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/openaimodel.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/sampling.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/sampling_utils.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/sigma_sampling.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/util.py
#  create mode 100644 model/sd/generative-models/sgm/modules/diffusionmodules/wrappers.py
#  create mode 100644 model/sd/generative-models/sgm/modules/distributions/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/distributions/distributions.py
#  create mode 100644 model/sd/generative-models/sgm/modules/ema.py
#  create mode 100644 model/sd/generative-models/sgm/modules/encoders/__init__.py
#  create mode 100644 model/sd/generative-models/sgm/modules/encoders/modules.py
#  create mode 100644 model/sd/generative-models/sgm/util.py
#  create mode 100644 model/sd/stablediffusion/.gitignore
#  create mode 100644 model/sd/stablediffusion/LICENSE
#  create mode 100644 model/sd/stablediffusion/LICENSE-MODEL
#  create mode 100644 model/sd/stablediffusion/README.md
#  create mode 100644 model/sd/stablediffusion/assets/model-variants.jpg
#  create mode 100644 model/sd/stablediffusion/assets/modelfigure.png
#  create mode 100644 model/sd/stablediffusion/assets/rick.jpeg
#  create mode 100644 model/sd/stablediffusion/assets/stable-inpainting/inpainting.gif
#  create mode 100644 model/sd/stablediffusion/assets/stable-inpainting/merged-leopards.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/d2i.gif
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/depth2fantasy.jpeg
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/depth2img01.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/depth2img02.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/merged-0000.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/merged-0004.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/merged-0005.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/midas.jpeg
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/depth2img/old_man.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/mountains-1.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/mountains-2.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/mountains-3.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/sketch-mountains-input.jpg
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/upscaling-in.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/img2img/upscaling-out.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/000002025.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/000002035.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0001.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0002.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0003.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0004.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0005.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/768/merged-0006.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/merged-0001.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/merged-0003.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/merged-0005.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/merged-0006.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/txt2img/merged-0007.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/upscaling/merged-dog.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/upscaling/sampled-bear-x4.png
#  create mode 100644 model/sd/stablediffusion/assets/stable-samples/upscaling/snow-leopard-x4.png
#  create mode 100644 model/sd/stablediffusion/configs/stable-diffusion/v2-inference-v.yaml
#  create mode 100644 model/sd/stablediffusion/configs/stable-diffusion/v2-inference.yaml
#  create mode 100644 model/sd/stablediffusion/configs/stable-diffusion/v2-inpainting-inference.yaml
#  create mode 100644 model/sd/stablediffusion/configs/stable-diffusion/v2-midas-inference.yaml
#  create mode 100644 model/sd/stablediffusion/configs/stable-diffusion/x4-upscaling.yaml
#  create mode 100644 model/sd/stablediffusion/environment.yaml
#  create mode 100644 model/sd/stablediffusion/ldm/data/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/data/util.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/autoencoder.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/ddim.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/ddpm.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/dpm_solver/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/dpm_solver/dpm_solver.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/dpm_solver/sampler.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/plms.py
#  create mode 100644 model/sd/stablediffusion/ldm/models/diffusion/sampling_util.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/attention.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/diffusionmodules/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/diffusionmodules/model.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/diffusionmodules/openaimodel.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/diffusionmodules/upscaling.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/diffusionmodules/util.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/distributions/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/distributions/distributions.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/ema.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/encoders/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/encoders/modules.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/image_degradation/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/image_degradation/bsrgan.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/image_degradation/bsrgan_light.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/image_degradation/utils/test.png
#  create mode 100644 model/sd/stablediffusion/ldm/modules/image_degradation/utils_image.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/api.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/__init__.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/base_model.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/blocks.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/dpt_depth.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/midas_net.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/midas_net_custom.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/transforms.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/midas/vit.py
#  create mode 100644 model/sd/stablediffusion/ldm/modules/midas/utils.py
#  create mode 100644 model/sd/stablediffusion/ldm/util.py
#  create mode 100644 model/sd/stablediffusion/modelcard.md
#  create mode 100644 model/sd/stablediffusion/requirements.txt
#  create mode 100644 model/sd/stablediffusion/scripts/gradio/depth2img.py
#  create mode 100644 model/sd/stablediffusion/scripts/gradio/inpainting.py
#  create mode 100644 model/sd/stablediffusion/scripts/gradio/superresolution.py
#  create mode 100644 model/sd/stablediffusion/scripts/img2img.py
#  create mode 100644 model/sd/stablediffusion/scripts/streamlit/depth2img.py
#  create mode 100644 model/sd/stablediffusion/scripts/streamlit/inpainting.py
#  create mode 100644 model/sd/stablediffusion/scripts/streamlit/superresolution.py
#  create mode 100644 model/sd/stablediffusion/scripts/tests/test_watermark.py
#  create mode 100644 model/sd/stablediffusion/scripts/txt2img.py
#  create mode 100644 model/sd/stablediffusion/setup.py
#  create mode 100644 model/sd/stablediffusion/src/blip/BLIP.gif
#  create mode 100644 model/sd/stablediffusion/src/blip/CODEOWNERS
#  create mode 100644 model/sd/stablediffusion/src/blip/CODE_OF_CONDUCT.md
#  create mode 100644 model/sd/stablediffusion/src/blip/LICENSE.txt
#  create mode 100644 model/sd/stablediffusion/src/blip/README.md
#  create mode 100644 model/sd/stablediffusion/src/blip/SECURITY.md
#  create mode 100644 model/sd/stablediffusion/src/blip/cog.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/bert_config.json
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/caption_coco.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/med_config.json
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/nlvr.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/nocaps.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/pretrain.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/retrieval_coco.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/retrieval_flickr.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/retrieval_msrvtt.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/configs/vqa.yaml
#  create mode 100644 model/sd/stablediffusion/src/blip/data/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/coco_karpathy_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/flickr30k_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/nlvr_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/nocaps_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/pretrain_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/utils.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/video_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/data/vqa_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/blip/demo.ipynb
#  create mode 100644 model/sd/stablediffusion/src/blip/eval_nocaps.py
#  create mode 100644 model/sd/stablediffusion/src/blip/eval_retrieval_video.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip_itm.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip_nlvr.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip_pretrain.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip_retrieval.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/blip_vqa.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/med.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/nlvr_encoder.py
#  create mode 100644 model/sd/stablediffusion/src/blip/models/vit.py
#  create mode 100644 model/sd/stablediffusion/src/blip/predict.py
#  create mode 100644 model/sd/stablediffusion/src/blip/pretrain.py
#  create mode 100644 model/sd/stablediffusion/src/blip/requirements.txt
#  create mode 100644 model/sd/stablediffusion/src/blip/train_caption.py
#  create mode 100644 model/sd/stablediffusion/src/blip/train_nlvr.py
#  create mode 100644 model/sd/stablediffusion/src/blip/train_retrieval.py
#  create mode 100644 model/sd/stablediffusion/src/blip/train_vqa.py
#  create mode 100644 model/sd/stablediffusion/src/blip/transform/randaugment.py
#  create mode 100644 model/sd/stablediffusion/src/blip/utils.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/.gitignore
#  create mode 100644 model/sd/stablediffusion/src/codeformer/LICENSE
#  create mode 100644 model/sd/stablediffusion/src/codeformer/README.md
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/CodeFormer_logo.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/color_enhancement_result1.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/color_enhancement_result2.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/imgsli_1.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/imgsli_2.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/imgsli_3.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/inpainting_result1.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/inpainting_result2.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/network.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/restoration_result1.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/restoration_result2.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/restoration_result3.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/assets/restoration_result4.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/VERSION
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/arcface_arch.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/arch_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/codeformer_arch.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/rrdbnet_arch.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/vgg_arch.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/archs/vqgan_arch.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/data/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/data/data_sampler.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/data/data_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/data/prefetch_dataloader.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/data/transforms.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/losses/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/losses/loss_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/losses/losses.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/metrics/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/metrics/metric_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/metrics/psnr_ssim.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/models/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/dcn/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/dcn/deform_conv.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/dcn/src/deform_conv_cuda.cpp
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/dcn/src/deform_conv_cuda_kernel.cu
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/dcn/src/deform_conv_ext.cpp
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/fused_act/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/fused_act/fused_act.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/fused_act/src/fused_bias_act.cpp
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/fused_act/src/fused_bias_act_kernel.cu
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/upfirdn2d/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/upfirdn2d/src/upfirdn2d.cpp
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/upfirdn2d/src/upfirdn2d_kernel.cu
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/ops/upfirdn2d/upfirdn2d.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/setup.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/train.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/dist_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/download_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/file_client.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/img_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/lmdb_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/logger.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/matlab_functions.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/misc.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/options.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/realesrgan_utils.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/registry.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/basicsr/utils/video_util.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/align_trans.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/matlab_cp2tform.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/retinaface/retinaface.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/retinaface/retinaface_net.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/retinaface/retinaface_utils.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/face_detector.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/common.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/experimental.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/yolo.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/yolov5l.yaml
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/models/yolov5n.yaml
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/autoanchor.py
#  create mode 100755 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/datasets.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/extract_ckpt.py
#  create mode 100755 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/general.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/detection/yolov5face/utils/torch_utils.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/parsing/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/parsing/bisenet.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/parsing/parsenet.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/parsing/resnet.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/utils/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/utils/face_restoration_helper.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/utils/face_utils.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/facelib/utils/misc.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inference_codeformer.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0143.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0240.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0342.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0345.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0368.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0412.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0444.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0478.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0500.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0599.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0717.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0720.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0729.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0763.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0770.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0777.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0885.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/0934.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/Solvay_conference_1927_0018.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/cropped_faces/Solvay_conference_1927_2_16.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/00.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/01.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/02.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/03.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/04.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/05.jpg
#  create mode 100644 model/sd/stablediffusion/src/codeformer/inputs/whole_imgs/06.png
#  create mode 100644 model/sd/stablediffusion/src/codeformer/requirements.txt
#  create mode 100755 model/sd/stablediffusion/src/codeformer/scripts/crop_align_face.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/scripts/download_pretrained_models.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/scripts/download_pretrained_models_from_gdrive.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/web-demos/hugging_face/app.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/web-demos/replicate/cog.yaml
#  create mode 100644 model/sd/stablediffusion/src/codeformer/web-demos/replicate/predict.py
#  create mode 100644 model/sd/stablediffusion/src/codeformer/weights/CodeFormer/.gitkeep
#  create mode 100644 model/sd/stablediffusion/src/codeformer/weights/README.md
#  create mode 100644 model/sd/stablediffusion/src/codeformer/weights/facelib/.gitkeep
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/.github/workflows/python-publish.yml
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/.gitignore
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/LICENSE
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/README.md
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/configs/config_32x32_small.json
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/configs/config_32x32_small_butterflies.json
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/configs/config_cifar10.json
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/configs/config_mnist.json
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/augmentation.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/config.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/evaluation.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/external.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/gns.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/layers.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/models/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/models/image_v1.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/sampling.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/k_diffusion/utils.py
#  create mode 100755 model/sd/stablediffusion/src/k-diffusion/make_grid.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/pyproject.toml
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/requirements.txt
#  create mode 100755 model/sd/stablediffusion/src/k-diffusion/sample.py
#  create mode 100755 model/sd/stablediffusion/src/k-diffusion/sample_clip_guided.py
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/setup.cfg
#  create mode 100644 model/sd/stablediffusion/src/k-diffusion/setup.py
#  create mode 100755 model/sd/stablediffusion/src/k-diffusion/train.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/License.txt
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/README.md
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/birddrawnbyachild.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/coco_scene_images_training.svg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/drin.jpg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/faceshq.jpg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/first_stage_mushrooms.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/first_stage_squirrels.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/imagenet.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/lake_in_the_mountains.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/mountain.jpeg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/scene_images_samples.svg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/stormy.jpeg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/sunset_and_ocean.jpg
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/assets/teaser.png
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/coco_cond_stage.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/coco_scene_images_transformer.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/custom_vqgan.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/drin_transformer.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/faceshq_transformer.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/faceshq_vqgan.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/imagenet_vqgan.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/imagenetdepth_vqgan.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/open_images_scene_images_transformer.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/configs/sflckr_cond_stage.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/environment.yaml
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/main.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/extract_depth.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/extract_segmentation.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/extract_submodel.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/make_samples.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/make_scene_samples.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/reconstruction_usage.ipynb
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/sample_conditional.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/sample_fast.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/scripts/taming-transformers.ipynb
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/setup.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/ade20k.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/annotated_objects_coco.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/annotated_objects_dataset.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/annotated_objects_open_images.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/base.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/coco.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/conditional_builder/objects_bbox.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/conditional_builder/objects_center_points.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/conditional_builder/utils.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/custom.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/faceshq.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/helper_types.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/image_transforms.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/imagenet.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/open_images_helper.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/sflckr.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/data/utils.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/lr_scheduler.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/models/cond_transformer.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/models/dummy_cond_stage.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/models/vqgan.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/diffusionmodules/model.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/discriminator/model.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/losses/__init__.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/losses/lpips.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/losses/segmentation.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/losses/vqperceptual.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/misc/coord.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/transformer/mingpt.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/transformer/permuter.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/util.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/modules/vqvae/quantize.py
#  create mode 100644 model/sd/stablediffusion/src/taming-transformers/taming/util.py
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git pull
# !git push https://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@github.com/changxu001/Stabl_Diffusion_UD.git
# !git status
# Out:
# <ontent/Stabl_Diffusion_UD/.git/MERGE_MSG" 6L, 308C▽  [>cMerge branch 'main' of https://github.com/changxu001/Stabl_Diffusion_UD into maiin
# # Please enter a commit message to explain why this merge is necessary,
# # especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               1,1All

# %%
# %cd /content/Stabl_Diffusion_UD/model/sd/stablediffusion/
# %mv .git/ .gitsub/
# %ls -a
#!git status
# Out:
# /content/Stabl_Diffusion_UD/model/sd/stablediffusion
# mv: cannot stat '.git/': No such file or directory
# ./       configs/          ldm/           modelcard.md      scripts/
# ../      environment.yaml  LICENSE        README.md         setup.py
# assets/  .gitignore        LICENSE-MODEL  requirements.txt  src/

# %%
# !git add -A
#!git restore --staged model/sd/stable-diffusion-webui

# %%
# %ls
# Out:
# 0718_Stable_Diffusion_Tool.ipynb  model/  README.md

# %% [markdown]
# ## **3 Install AUTOMATIC1111 to the folder**

# %%
#@markdown # Install/Update AUTOMATIC1111 repo
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import base64

blasphemy=base64.b64decode(("d2VidWk=").encode('ascii')).decode('ascii')

if not os.path.exists('/content/Stabl_Diffusion_UD/model/sd/stable-diffusion-webui'):
  print('Automatic1111 not exist, downloading...')

  with capture.capture_output() as cap:
    def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
    fgitclone = "git clone --depth 1"
    # %mkdir -p /content/Stabl_Diffusion_UD/model/sd
    # %cd /content/Stabl_Diffusion_UD/model/sd
    # !git clone -q --branch master https://github.com/AUTOMATIC1111/stable-diffusion-$blasphemy
    # !mkdir -p /content/Stabl_Diffusion_UD/model/sd/stable-diffusion-$blasphemy/cache/
    os.environ['TRANSFORMERS_CACHE']=f"/content/Stabl_Diffusion_UD/model/sd/stable-diffusion-"+blasphemy+"/cache"

  with capture.capture_output() as cap:
    # %cd /content/Stabl_Diffusion_UD/model/sd/stable-diffusion-$blasphemy/
    # !git reset --hard
    # !git checkout master
    time.sleep(1)
    # !rm webui.sh
    # !git pull
  clear_output()
  inf('\u2714 Done','success', '50px')


print('Good. Automatic1111 downloaded.')
# Out:
# Good. Automatic1111 downloaded.

# %% [markdown]
# ## **4 Install Stable Diffusion + Clip Embedding**

# %%
#@markdown # Requirements
if not os.path.exists('/content/Stabl_Diffusion_UD/model/sd/stablediffusion'):
  print('Stable Diffusion not exist. Installing....')
  with capture.capture_output() as cap:
    # %cd /content/
    # !wget -q -i https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/Dependencies/A1111.txt
    # !dpkg -i *.deb
    if not os.path.exists('/content/Stabl_Diffusion_UD/model/sd/stablediffusion'):
      print('Stable Diffusion not exist. Installing....')
      # !tar -C /content/Stabl_Diffusion_UD/model --zstd -xf sd_rep.tar.zst
      # !tar -C / --zstd -xf gcolabdeps.tar.zst

    # !rm *.deb | rm *.zst | rm *.txt
    # %env LD_PRELOAD=libtcmalloc.so
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
    os.environ['PYTHONWARNINGS'] = 'ignore'
    # !pip install open-clip-torch==2.20.0 -qq --no-deps


print('Good. Stable Diffusion downloaded')
# Out:
# Good. Stable Diffusion downloaded

# %% [markdown]
# ## **5 Download Online or Link to Local Pretrained Model**

# %%
#@markdown # Model Download/Load
Model_Version = "1.5" #@param [ "1.5", "v1.5 Inpainting ", "V2.1-512px", "V2.1-768px"]

Redownload_the_original_model = False #@param {type:"boolean"}

def rmv():
  # !wget -q -O /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/models/Stable-diffusion/model.ckpt https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/precompiled/README.md
  # !mv /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/models/Stable-diffusion/model.ckpt /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/models/Stable-diffusion/trashfile.f
  time.sleep(2)
  # !rm /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/models/Stable-diffusion/trashfile.f
  clear_output()

if Redownload_the_original_model:
  with capture.capture_output() as cap:
    rmv()

#@markdown Or
Path_to_MODEL = "" #@param {type:"string"}
#@markdown - Insert the full path of your trained model or to a folder containing multiple models

#@markdown Or
MODEL_LINK = "" #@param {type:"string"}
safetensors = False #@param {type:"boolean"}
Use_temp_storage = False #@param {type:"boolean"}



def newmdl():

    if not os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-v1-5"
      if os.path.exists('/content/stable-diffusion-v1-5/unet/diffusion_pytorch_model.bin'):
        # !wget -q -O stable-diffusion-v1-5/vae/diffusion_pytorch_model.bin https://huggingface.co/stabilityai/sd-vae-ft-mse/resolve/main/diffusion_pytorch_model.bin
        # !wget -q -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-v1-5"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "/content/gdrive/{mainpth}/sd/stable-diffusion-{blasphemy}/models/Stable-diffusion/model.ckpt"@' /content/convertosd.py
        clear_output()
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'):
          model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")

    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V1.5','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-v1-5'):
      # !rm -r /content/stable-diffusion-v1-5

    return model

def V2():

    if not os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'):
      # %cd /content/
      clear_output()
      # !mkdir "/content/stable-diffusion-V2"
      # %cd "/content/stable-diffusion-V2"
      # !git init
      # !git lfs install --system --skip-repo
      if Model_Version == "V2.1-768px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1"
      elif Model_Version == "V2.1-512px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1-base"
      # !git config core.sparsecheckout true
      # !echo -e "scheduler\ntext_encoder\ntokenizer\nunet\nvae\nfeature_extractor\nmodel_index.json\n!*.safetensors" > .git/info/sparse-checkout
      # !git pull origin fp16
      # %cd /content
      # !wget -O convertosdv2.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosdv2.py
      clear_output()
      # !python /content/convertosdv2.py --fp16 /content/stable-diffusion-V2 /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/models/Stable-diffusion/model.ckpt
      # !rm /content/convertosdv2.py
      if os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'):
        model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'
        clear_output()
        inf('\u2714 Done','success', '50px')
      else:
        inf('\u2718 Something went wrong, try again','danger', "250px")

    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/model.ckpt'
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V2','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git
      # !rm -r /content/convertosdv2.py
    if os.path.exists('/content/stable-diffusion-V2'):
      # !rm -r /content/stable-diffusion-V2

    return model

def inpmdl():

    if not os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-inpainting"
      if os.path.exists('/content/stable-diffusion-inpainting'):
        # !$fgitclone "https://huggingface.co/stabilityai/sd-vae-ft-mse"
        # !rm -r /content/stable-diffusion-inpainting/vae
        # !mv /content/sd-vae-ft-mse /content/stable-diffusion-inpainting/vae
        # !wget -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-inpainting"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "/content/gdrive/{mainpth}/sd/stable-diffusion-{blasphemy}/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"@' /content/convertosd.py
        clear_output()
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists('/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'):
          model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")


    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'
      clear_output()
      inf('\u2714 inpainting model already exists','primary', '250px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-inpainting'):
      # !rm -r /content/stable-diffusion-inpainting

    return model

if (Path_to_MODEL !=''):
  if os.path.exists(str(Path_to_MODEL)):
    inf('\u2714 Using the trained model.','success', '200px')

  else:
      while not os.path.exists(str(Path_to_MODEL)):
        inf('\u2718 Wrong path, use the colab file explorer to copy the path : ','danger', "400px")
        Path_to_MODEL=input()
      if os.path.exists(str(Path_to_MODEL)):
        inf('\u2714 Using the trained model.','success', '200px')

  model=Path_to_MODEL

elif MODEL_LINK != "":
  gdrv='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/models/Stable-diffusion'
  tmp="/content"
  pth=tmp if Use_temp_storage else gdrv
  # %cd $pth
  clear_output()
  if not safetensors:
    modelname="model.ckpt"
  else:
    modelname="model.safetensors"
  # !gdown --fuzzy -O $modelname "$MODEL_LINK"
  if os.path.exists(f'{pth}/{modelname}') and os.path.getsize(f'{pth}/{modelname}') > 1810671599:
      model=f'{pth}/{modelname}'
      clear_output()
      inf('\u2714 Model downloaded, using the trained model.','success', '350px')
  else:
    if Use_temp_storage:
      # !rm $pth/$modelname
    else:
      rmv()
    inf('\u2718 Wrong link, check that the link is valid','danger', "300px")


elif Model_Version=="1.5":
  model=newmdl()

elif Model_Version=="V2.1-512px" or Model_Version=="V2.1-768px":
  model=V2()

else:
   model=inpmdl()
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %% [markdown]
# ## **6 Download Control Net**

# %%
#@markdown # ControlNet
from torch.hub import download_url_to_file
from urllib.parse import urlparse
import re
from subprocess import run

Model = "None" #@param [ "None", "All (21GB)", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Tile", "T2iadapter_Models"]

v2_Model = "None" #@param [ "None", "All", "Canny", "Depth", "HED", "OpenPose", "Scribble"]

#@markdown - Download/update ControlNet extension and its models

def download(url, model_dir):

    filename = os.path.basename(urlparse(url).path)
    pth = os.path.abspath(os.path.join(model_dir, filename))
    if not os.path.exists(pth):
        print('Downloading: '+os.path.basename(url))
        download_url_to_file(url, pth, hash_prefix=None, progress=True)
    else:
      print(f"[1;32mThe model {filename} already exists[0m")

Canny='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth'
Depth='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth'
Lineart='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth'
MLSD='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth'
Normal='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth'
OpenPose='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth'
Scribble='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth'
Seg='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth'
ip2p='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth'
Shuffle='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth'
Inpaint='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth'
Softedge='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth'
Lineart_Anime='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth'
Tile='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'

with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/extensions
  if not os.path.exists("sd-webui-controlnet"):
    # !git clone https://github.com/Mikubill/sd-$blasphemy-controlnet.git
    # %cd /content
  else:
    # %cd sd-webui-controlnet
    # !git reset --hard
    # !git pull
    # %cd /content

mdldir='/content/gdrive/'+mainpth+'/sd/stable-diffusion-'+blasphemy+'/extensions/sd-webui-controlnet/models'
for filename in os.listdir(mdldir):
  if "_sd14v1" in filename:
    renamed = re.sub("_sd14v1", "-fp16", filename)
    os.rename(os.path.join(mdldir, filename), os.path.join(mdldir, renamed))

# !wget -q -O CN_models.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models.txt
# !wget -q -O CN_models_v2.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models_v2.txt

with open("CN_models.txt", 'r') as f:
  mdllnk = f.read().splitlines()
with open("CN_models_v2.txt", 'r') as d:
  mdllnk_v2 = d.read().splitlines()

# !rm CN_models.txt CN_models_v2.txt

with capture.capture_output() as cap:
  cfgnames=[os.path.basename(url).split('.')[0]+'.yaml' for url in mdllnk_v2]
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/extensions/sd-webui-controlnet/models
  for name in cfgnames:
      run(['cp', 'cldm_v21.yaml', name])
  # %cd /content

if Model == "All (21GB)":
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()

elif Model == "T2iadapter_Models":
  mdllnk=list(filter(lambda x: 't2i' in x, mdllnk))
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()

elif Model == "None":
    pass
    clear_output()

else:
  download(globals()[Model], mdldir)
  clear_output()

Canny='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_canny.safetensors'
Depth='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_depth.safetensors'
HED='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_hed.safetensors'
OpenPose='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_openposev2.safetensors'
Scribble='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_scribble.safetensors'

if v2_Model == "All":
  for lnk_v2 in mdllnk_v2:
      download(lnk_v2, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

elif v2_Model == "None":
    pass
    clear_output()
    inf('\u2714 Done','success', '50px')

else:
  download(globals()[v2_Model], mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %% [markdown]
# ## **7 Start the Gradio UI Space**

# %%
#@markdown # Start Stable-Diffusion
from IPython.utils import capture
import time
import sys
import fileinput
from pyngrok import ngrok, conf

Use_Cloudflare_Tunnel = False #@param {type:"boolean"}
#@markdown - Offers better gradio responsivity

Ngrok_token = "" #@param {type:"string"}

#@markdown - Input your ngrok token if you want to use ngrok server

User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - Add credentials to your Gradio interface (optional)

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""


with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/modules/
  # !wget -q -O paths.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/paths.py
  # !wget -q -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-$blasphemy/master/modules/extras.py
  # !wget -q -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-$blasphemy/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.10/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/blocks.py
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/

  # !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/modules/sd_models.py
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/webui.py
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/modules/extras.py
  # !sed -i 's@/content/gdrive/MyDrive/sd/stablediffusion@/content/gdrive/{mainpth}/sd/stablediffusion@' /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/modules/paths.py
  # !sed -i 's@print(\"No module.*@@' /content/gdrive/$mainpth/sd/stablediffusion/ldm/modules/diffusionmodules/model.py
  # !sed -i 's@\["sd_model_checkpoint"\]@\["sd_model_checkpoint", "sd_vae", "CLIP_stop_at_last_layers", "inpainting_mask_weight", "initial_noise_multiplier"\]@g' /content/gdrive/MyDrive/sd/stable-diffusion-$blasphemy/modules/shared.py

share=''
if Ngrok_token!="":
  ngrok.kill()
  srv=ngrok.connect(7860, pyngrok_config=conf.PyngrokConfig(auth_token=Ngrok_token) , bind_tls=True).public_url

  for line in fileinput.input('/usr/local/lib/python3.10/dist-packages/gradio/blocks.py', inplace=True):
    if line.strip().startswith('self.server_name ='):
        line = f'            self.server_name = "{srv[8:]}"\n'
    if line.strip().startswith('self.protocol = "https"'):
        line = '            self.protocol = "https"\n'
    if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
        line = ''
    if line.strip().startswith('else "http"'):
        line = ''
    sys.stdout.write(line)

elif Use_Cloudflare_Tunnel:
  with capture.capture_output() as cap:
    # !pkill cloudflared
    time.sleep(4)
    # !nohup cloudflared tunnel --url http://localhost:7860 > /content/srv.txt 2>&1 &
    time.sleep(4)
    # !grep -o 'https[^[:space:]]*\.trycloudflare.com' /content/srv.txt >/content/srvr.txt
    time.sleep(2)
    srv= getoutput('cat /content/srvr.txt')

    for line in fileinput.input('/usr/local/lib/python3.10/dist-packages/gradio/blocks.py', inplace=True):
      if line.strip().startswith('self.server_name ='):
          line = f'            self.server_name = "{srv[8:]}"\n'
      if line.strip().startswith('self.protocol = "https"'):
          line = '            self.protocol = "https"\n'
      if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
          line = ''
      if line.strip().startswith('else "http"'):
          line = ''
      sys.stdout.write(line)

    # !rm /content/srv.txt /content/srvr.txt

else:
  share='--share'

try:
  model
  if os.path.isfile(model):
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --opt-sdp-attention $auth --disable-console-progressbars
  else:
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --opt-sdp-attention $auth --disable-console-progressbars
except:
   # !python /content/gdrive/$mainpth/sd/stable-diffusion-$blasphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --opt-sdp-attention $auth --disable-console-progressbars
# Out:
# 2023-07-17 20:10:38,535 - ControlNet - INFO - ControlNet v1.1.232
# ControlNet preprocessor location: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads
# 2023-07-17 20:10:38,681 - ControlNet - INFO - ControlNet v1.1.232
# Calculating sha256 for /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt: preload_extensions_git_metadata for 8 extensions took 0.09s
# 4c86efd062ea772972dd068c3870773f1fd9a37ba9a288ee79ec848448ce7785
# Loading weights [4c86efd062] from /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt
# Creating model from config: /content/gdrive/MyDrive/sd/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json100% 961k/961k [00:00<00:00, 1.12MB/s]
# Downloading (…)olve/main/merges.txt  0% 0.00/525k [00:00<?, ?B/s]Running on public URL: https://797c2f9002b8f8c7c8.gradio.live
# ✔ Connected
# Downloading (…)olve/main/merges.txt100% 525k/525k [00:00<00:00, 1.23MB/s]
# Startup time: 36.1s (import torch: 9.4s, import gradio: 2.1s, import ldm: 1.0s, other imports: 2.8s, load scripts: 2.0s, create ui: 1.0s, gradio launch: 17.7s, add APIs: 0.2s).
# Downloading (…)cial_tokens_map.json100% 389/389 [00:00<00:00, 1.83MB/s]
# Downloading (…)okenizer_config.json100% 905/905 [00:00<00:00, 3.49MB/s]
# Downloading (…)lve/main/config.json100% 4.52k/4.52k [00:00<00:00, 19.1MB/s]
# Applying attention optimization: sdp... done.
# Textual inversion embeddings loaded(0):
# Model loaded in 29.2s (calculate hash: 8.8s, load weights from disk: 6.9s, create model: 4.8s, apply weights to model: 2.9s, apply half(): 3.0s, move model to device: 2.5s, calculate empty prompt: 0.2s).
# Interrupted with signal 2 in <frame at 0xa55e0910, file '/usr/lib/python3.10/threading.py', line 324, code wait>
